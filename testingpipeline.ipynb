# %%
import pickle
import numpy as np 
import warnings
warnings.filterwarnings('ignore')

# %%
pipe=pickle.load(open('pipe.pkl','rb'))

# %% [raw]
# ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']

# %%
## ASSUMING USER INPUT: 
test_input2=np.array(['2', 'male', 31.0, 0, 0, 70.5, 'S'],dtype=object).reshape(1,7)

# %%
pipe.predict(test_input2)
# Out:
# array([0])

# %% [markdown]
# ## HE WILL NOT SURVIVE!!!!
